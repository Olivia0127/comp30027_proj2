# %%
import pandas as pd
import numpy as np
from collections import defaultdict as dd
import re
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
data = pd.read_csv("./project_data_files/book_rating_train.csv")
test_df = pd.read_csv("./project_data_files/book_rating_test.csv")
print('Full Data:', len(data))
# Out:
# Full Data: 23063

# %%
data_label = data['rating_label'].value_counts()
plt.figure(figsize = (5,5))
plt.title(f'label distribution');
plt.pie(data_label, labels = [3, 4, 5], autopct='%1.1f%%', colors = ['#B3CDE3', '#FBB4AE','#CCEBC5'], explode=[0.05, 0.05, 0.05])
plt.savefig(f'label_distribution.png')
